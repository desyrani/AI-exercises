# %% [markdown]
# # Pandas
#
# ![](http://pandas.pydata.org/_static/pandas_logo.png)
# [Pandas](http://pandas.pydata.org/) is a software library written for the Python programming language for data manipulation and analysis. In particular, it offers data structures and operations for manipulating numerical tables and time series. Pandas is free software released under the three-clause BSD license. The name is derived from the term _panel data_, an econometrics term for multidimensional structured data sets.

# %% [markdown]
# ## DataFrames
#
#
# A data frame is like a table, with rows and columns (e.g., as in SQL or Excel).
# Except that :
#   - The rows can be indexed by something interesting (there is special support for labels like categorical and timeseries data).
#   - Cells can store any Python object. Like in SQL, columns must have a homogenous type.
#   - Instead of "NULL", the name for a non-existent value is "NA".  Unlike R, Python's data frames only support NAs in columns of some data types (basically: floating point numbers and 'objects') -- but this is mostly a non-issue (because it will "up-type" integers to float64, etc.)
#
# Each of a ```DataFrame```'s columns are an individual ```Series```, (more correctly, a dataframe is a dictionary of Series).  The entires series must have a homogenous type.

# %%
#import pandas library as pd
import pandas as pd
#import matplotlib library as plt
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# # Dataframe

# %% [markdown]
# ## 1. Merge two lists using zip function
# ## 2. Create a Dataframe using a list
# ## 3. Create a Dataframe using Series
# ## 4. Dataframe Functions
# ### a. df.head()
# ### b. df.tail()
# ### c. df.info()
# ### d. df.describe()
# ### e. df.T
# ### f. df['Area']
# ### g. type(df['Area'])
# ### h. df.sort_values('Area', ascending=False)
# ### i. df['Area'].sum()
# ### j. df['Area'][9:11].sum()
# ### k. Create a graph using matplot library

# %% [markdown]
# ## 1. Merge two lists using zip function

# %% [markdown]
# Example 1
#
# Let's make a dataset that consists of Malaysian States
# and the size of each state in $km^2$.  Let's try and rank
# the states of Malaysia by land area, and figure out if East
# Malaysia is larger or smaller than West Malaysia

# %% [markdown]
# Use the zip function to merge the two lists together

# %% [markdown]
# # **DESY KHALIDA MAHARANI _ AIU21102283**

# %%
states = ['Johor', 'Kedah', 'Kelantan', 'Melaka', 'Negeri Sembilan', 'Pahang', 'Perak', 'Perlis', 'Penang', 'Sabah', 'Saarawak', 'Selangor', 'Trengganu']
area = [19210, 9500, 15099, 1664, 6686, 36137, 21035, 821, 1048, 73631, 124450, 8104, 13035]
covid19 = [16760, 5253, 2927, 3078, 11092, 2663, 5526, 154, 7275, 47139, 3499, 55369, 1613]

# %%
type(states)
# Out:
# list

# %%
state_area = zip(states, area)
state_area

# %%
type(state_area)
# Out:
# zip

# %%
# Area Data Set
state_area  = list(zip(states, area))
state_area
# Out:
# [('Johor', 19210),
#  ('Kedah', 9500),
#  ('Kelantan', 15099),
#  ('Melaka', 1664),
#  ('Negeri Sembilan', 6686),
#  ('Pahang', 36137),
#  ('Perak', 21035),
#  ('Perlis', 821),
#  ('Penang', 1048),
#  ('Sabah', 73631),
#  ('Saarawak', 124450),
#  ('Selangor', 8104),
#  ('Trengganu', 13035)]

# %%
type (state_area)
# Out:
# list

# %% [markdown]
# ## 2. Create a Dataframe using a list

# %% [markdown]
# ***df*** will be a ***DataFrame*** object. You can think of this object holding the contents of states in a format similar to a sql table or an excel spreadsheet. Lets take a look below at the contents inside ***df***.

# %%
import pandas as pd

# %%
dfl = pd.DataFrame(data = state_area, columns = ['State', 'Area'])

# %%
dfl
# Out:
#               State    Area
# 0             Johor   19210
# 1             Kedah    9500
# 2          Kelantan   15099
# 3            Melaka    1664
# 4   Negeri Sembilan    6686
# 5            Pahang   36137
# 6             Perak   21035
# 7            Perlis     821
# 8            Penang    1048
# 9             Sabah   73631
# 10         Saarawak  124450
# 11         Selangor    8104
# 12        Trengganu   13035

# %% [markdown]
# ## 3. Create a Dataframe using Series

# %%
purchase_1 = pd.Series({'Name' : 'Chris',
                        'Item_Purchase' : 'Dog Food',
                        'Cost' : 22.50})
purchase_2 = pd.Series({'Name' : 'Kevyn',
                        'Item_Purchase' : 'Kitty Litter',
                        'Cost' : 2.50})
purchase_3 = pd.Series({'Name' : 'Vynod',
                        'Item_Purchase' : 'Bird Seed',
                        'Cost' : 5.00})
dfs = pd.DataFrame([purchase_1, purchase_2, purchase_3,], index = ['Store 1', 'Store 2', 'Store 3'])
dfs
# Out:
#           Name Item_Purchase  Cost
# Store 1  Chris      Dog Food  22.5
# Store 2  Kevyn  Kitty Litter   2.5
# Store 3  Vynod     Bird Seed   5.0

# %%
# @title Name

from matplotlib import pyplot as plt
import seaborn as sns
dfs.groupby('Name').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
type(dfs)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ## 4. Dataframe Functions

# %% [markdown]
# ### Dataframe from list

# %% [markdown]
# ### Dataframe from Series
#
# Exercise:
#
#
# *   Show the first five  rows
# *   Show the last five rows
#
#
# *   Show the info and description of the dataframe
# *   Calculate the sum of sales for all stores
#
#
# *   Calculate the amount spent by any two customers
# *   Plot suitable graph

# %%
# a. First five rows from dataframe
dfl.head()
# Out:
#              State   Area
# 0            Johor  19210
# 1            Kedah   9500
# 2         Kelantan  15099
# 3           Melaka   1664
# 4  Negeri Sembilan   6686

# %%
# b. Last five rows from dataframe
dfl.tail()
# Out:
#         State    Area
# 8      Penang    1048
# 9       Sabah   73631
# 10   Saarawak  124450
# 11   Selangor    8104
# 12  Trengganu   13035

# %%
# c. General information
dfl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13 entries, 0 to 12
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   State   13 non-null     object
#  1   Area    13 non-null     int64
# dtypes: int64(1), object(1)
# memory usage: 336.0+ bytes

# %%
# d. Provide statistical summary for the whole dataset
dfl.describe()
# Out:
#                 Area
# count      13.000000
# mean    25416.923077
# std     35627.125329
# min       821.000000
# 25%      6686.000000
# 50%     13035.000000
# 75%     21035.000000
# max    124450.000000

# %%
# e. Transpose dataframe
a = dfl.T
a
# Out:
#           0      1         2       3                4       5      6       7   \
# State  Johor  Kedah  Kelantan  Melaka  Negeri Sembilan  Pahang  Perak  Perlis
# Area   19210   9500     15099    1664             6686   36137  21035     821
#
#            8      9         10        11         12
# State  Penang  Sabah  Saarawak  Selangor  Trengganu
# Area     1048  73631    124450      8104      13035

# %%
# Find the values of the specified coloumn
dfl['Area']
# Out:
# 0      19210
# 1       9500
# 2      15099
# 3       1664
# 4       6686
# 5      36137
# 6      21035
# 7        821
# 8       1048
# 9      73631
# 10    124450
# 11      8104
# 12     13035
# Name: Area, dtype: int64

# %%
#g Find the type of column
type(dfl)
# Out:
# pandas.core.frame.DataFrame

# %%
# h. Rangking of land area
dfl1 = dfl.sort_values('Area', ascending = False)
dfl1
# Out:
#               State    Area
# 10         Saarawak  124450
# 9             Sabah   73631
# 5            Pahang   36137
# 6             Perak   21035
# 0             Johor   19210
# 2          Kelantan   15099
# 12        Trengganu   13035
# 1             Kedah    9500
# 11         Selangor    8104
# 4   Negeri Sembilan    6686
# 3            Melaka    1664
# 8            Penang    1048
# 7            Perlis     821

# %%
# Area of East Malaysia
print('East Malaysia Size: ', dfl)
# Out:
# East Malaysia Size:                State    Area
# 0             Johor   19210
# 1             Kedah    9500
# 2          Kelantan   15099
# 3            Melaka    1664
# 4   Negeri Sembilan    6686
# 5            Pahang   36137
# 6             Perak   21035
# 7            Perlis     821
# 8            Penang    1048
# 9             Sabah   73631
# 10         Saarawak  124450
# 11         Selangor    8104
# 12        Trengganu   13035

# %%
# Excluding WPs, Area of West Malaysia excluding WPs
print('West Malaysia Size: ', dfl['Area'].sum() - dfl['Area'][9:11].sum())
# Out:
# West Malaysia Size:  132339

# %%
import numpy as np

# %%
# Create graph
dfl1['Area'].plot.bar()
plt.xticks(np.arange(13), (dfl1['State']))
plt.xlabel('Malaysian State')
plt.ylabel('Land Area in $km^2$')
plt.title('Malaysian States by Land Area')
plt.show()

# %% [markdown]
# # **EXERCISES**

# %%
purchase_1 = pd.Series({'Name' : 'Chris',
                        'Item_Purchase' : 'Dog Food',
                        'Cost' : 22.50})
purchase_2 = pd.Series({'Name' : 'Kevyn',
                        'Item_Purchase' : 'Kitty Litter',
                        'Cost' : 2.50})
purchase_3 = pd.Series({'Name' : 'Vynod',
                        'Item_Purchase' : 'Bird Seed',
                        'Cost' : 5.00})
dfs = pd.DataFrame([purchase_1, purchase_2, purchase_3,], index = ['Store 1', 'Store 2', 'Store 3'])
dfs
# Out:
#           Name Item_Purchase  Cost
# Store 1  Chris      Dog Food  22.5
# Store 2  Kevyn  Kitty Litter   2.5
# Store 3  Vynod     Bird Seed   5.0

# %%
# First five rows
dfs.head()
# Out:
#           Name Item_Purchase  Cost
# Store 1  Chris      Dog Food  22.5
# Store 2  Kevyn  Kitty Litter   2.5
# Store 3  Vynod     Bird Seed   5.0

# %%
# Last five rows
dfs.tail()
# Out:
#           Name Item_Purchase  Cost
# Store 1  Chris      Dog Food  22.5
# Store 2  Kevyn  Kitty Litter   2.5
# Store 3  Vynod     Bird Seed   5.0

# %%
# Info
dfs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3 entries, Store 1 to Store 3
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Name           3 non-null      object
#  1   Item_Purchase  3 non-null      object
#  2   Cost           3 non-null      float64
# dtypes: float64(1), object(2)
# memory usage: 204.0+ bytes

# %%
# Description
dfs.describe()
# Out:
#             Cost
# count   3.000000
# mean   10.000000
# std    10.897247
# min     2.500000
# 25%     3.750000
# 50%     5.000000
# 75%    13.750000
# max    22.500000

# %%
# Sum from all stores
dfs.sum()
# Out:
# Name                           ChrisKevynVynod
# Item_Purchase    Dog FoodKitty LitterBird Seed
# Cost                                      30.0
# dtype: object

# %%
# h. Rangking of cost
dfs1 = dfs.sort_values('Cost', ascending = False)
dfs1
# Out:
#           Name Item_Purchase  Cost
# Store 1  Chris      Dog Food  22.5
# Store 3  Vynod     Bird Seed   5.0
# Store 2  Kevyn  Kitty Litter   2.5

# %%
# Create graph
dfs['Cost'].plot.bar()
plt.xticks(np.arange(3), (dfs['Cost']))
plt.xlabel('Store Name')
plt.ylabel('Cost')
plt.title('Cost by Each Store')
plt.show()
